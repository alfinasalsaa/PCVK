# %% [markdown]
# <a href="https://colab.research.google.com/github/alfinasalsaa/PCVK/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# nama anggota kelompok
# Alfina Salsabilla 2141720044
# M. Rafi Prabowo 2141720239
# Syaikhul Syafwan R 2141720105

# %%
from google.colab import drive

#accessing My google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten1.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)    #konversi cahnnel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten1.jpg' , cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 =cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)


#tampillkan plot dengan canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat pada titik2 pt1 dan pt2

cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 chenel yang mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# Jawaban Pertanyaan :
# 1. perbedaan gambar yang ditampilkan denegna menggunakan matplotlib dapat memvisualisasikan data seperti garis, diagram batang, scatter plot, selain itu dengan menggunakan matplotlib kiat bisa menyesuaikan visualisasi gambar dari warna dan aspek lainnya.
#
# 2. perbedaan antara int16 dan int32 adalah dengan menggunakan int16 kita akan mendapatkan gambar hitam dengan kualitas yang tidak terlalu tajam atau tidak sehitam(sepekat) warna hitam ketika kita menggunakan int32. int16 akan memakan lebih sedikit memori dibandingkan dengan int32.
#
# 3. kegunaan kode tersebut adalah untuk menampilkan gambar pada google colab dengan mengunakan OpenCv tanpa harus menyimpan gambar terlebih dahulu, atau langkah tambahan lainnya.
#
# 4. dengan kode tersebut memungkinkan kita untuk bekerja dengan gambar pada phyton dimana gmabar tersebut memerlukan masih memerlukan pemrosesan lanjutan.

# %% [markdown]
# E. TUGAS
# 1. dengan menggunakan figsize maka ukuran pixel gambar tidak akan berubah karena yang berubah hanya ukuran gambar yang ditampilkan pada plot

# %%
# TUGAS NO. 2 RED-BLUE

import cv2 as cv
import matplotlib.pyplot as plt

# Membaca gambar dalam warna asli
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')

# Membuat citra baru hanya dengan saluran Red-Blue
red_blue = img.copy()
red_blue[:, :, 1] = 0  # Set saluran hijau menjadi 0 (hanya tinggalkan saluran merah dan biru)

# Menampilkan citra dalam saluran Red-Blue
plt.imshow(cv.cvtColor(red_blue, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Red-Blue Channel')
plt.show()

# %%
# TUGAS NO. 2 GREEN-BLUE
import cv2 as cv
import matplotlib.pyplot as plt

# Membaca gambar dalam warna asli
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')

# Membuat citra baru hanya dengan saluran Green-Blue
green_blue = img.copy()
green_blue[:, :, 2] = 0  # Set saluran merah menjadi 0 (hanya tinggalkan saluran hijau dan biru)

# Menampilkan citra dalam saluran Green-Blue
plt.imshow(cv.cvtColor(green_blue, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Green-Blue Channel')
plt.show()

# %%
# TUGAS NO.3
import cv2
import matplotlib.pyplot as plt

# Membaca citra
image = cv2.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')

# Memotong bagian tertentu dari citra
cropped_image = image[20:116, 25:121]

# Menampilkan citra hasil pemotongan
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
plt.title('Cropped Image')
plt.show()

# %%
# TUGAS NO 4
import cv2 as cv
import matplotlib.pyplot as plt

# Membaca gambar dalam warna asli
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')

# Membuat citra baru hanya dengan saluran Red-Blue
red_blue = img.copy()
red_blue[:, :, 1] = 0  # Set saluran hijau menjadi 0 (hanya tinggalkan saluran merah dan biru)

# Memotong bagian tertentu dari citra
cropped_image = image[5:30]

# Menampilkan citra dalam saluran Red-Blue
plt.imshow(cv.cvtColor(cropped_image, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.title('Red Channel')
plt.show()

# %%
# TUGAS NO.5

 # TUGAS NO 5
import cv2 as cv
import matplotlib.pyplot as plt
import random
# Membaca gambar dalam warna asli
img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')

#
x = random.randint(0, image.shape[1])  # Acak koordinat x1
y = random.randint(0, image.shape[0])
x1 = random.randint(0, image.shape[1])
y1 = random.randint(0, image.shape[0])
x2 = random.randint(0, image.shape[1])
y2 = random.randint(0, image.shape[0])
x3 = random.randint(0, image.shape[1])  # Acak koordinat x1
y3 = random.randint(0, image.shape[0])
x4 = random.randint(0, image.shape[1])  # Acak koordinat x1
y4 = random.randint(0, image.shape[0])
x5 = random.randint(0, image.shape[1])  # Acak koordinat x1
y5 = random.randint(0, image.shape[0])
cv.rectangle(img,pt1=(x,y),pt2=(x1,y1),color=(255,0,0),thickness=10)
cv.rectangle(img,pt1=(x,y),pt2=(x2,y2),color=(0,255,0),thickness=10)
cv.rectangle(img,pt1=(x,y),pt2=(x3,y3),color=(0,0,255),thickness=10)
cv.rectangle(img,pt1=(x,y),pt2=(x4,y4),color=(0,255,255),thickness=10)
cv.rectangle(img,pt1=(x,y),pt2=(x5,y5),color=(255,0,255),thickness=10)
plt.imshow(img)

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')
img_flip =cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampillkan plot dengan canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img_flip)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from skimage import io

# Membaca gambar

image = io.imread('/content/drive/MyDrive/PCVK/Images/orang.jpg')

# Koordinat wajah (contoh)
x_face, y_face, width_face, height_face = 200, 0, 200, 200

# Membuat plot
fig, ax = plt.subplots(1)

# Menampilkan gambar asli
ax.imshow(image)

# Membuat rectangle pada wajah
face_rectangle = patches.Rectangle((x_face, y_face), width_face, height_face, linewidth=2, edgecolor='r', facecolor='none')
ax.add_patch(face_rectangle)

# Koordinat pusat dan radius circle (contoh)
x_center, y_center, radius = 300, 100, 75
# Membuat circle pada wajah
face_circle = patches.Circle((x_center, y_center), radius, linewidth=2, edgecolor='g', facecolor='none')
ax.add_patch(face_circle)

# Menampilkan gambar dengan rectangle dan circle
plt.show()

# %%
image= cv.imread('/content/drive/MyDrive/PCVK/Images/kitten2.jpg')

red = image.copy()
red[:, :, 2] = 0
red[:, :, 1] = 0
tinggi,lebar,saluran= image.shape

cv2.rectangle(red,pt1=(0,tinggi),pt2=(50,400),color=(0,255,0),thickness = 3)
plt.imshow(red)

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(red,text='kitten2.jpg',org=(10,300),fontFace=font,fontScale=1,color=(255,255,255),thickness=2,lineType=cv2.LINE_AA)
plt.imshow(red)

# %%
gambar='/content/drive/MyDrive/PCVK/Images/KTP.png'
gambarPolos= cv2.imread(gambar)
converted=cv2.cvtColor(gambarPolos,cv2.COLOR_BGR2RGB)
plt.imshow(converted)

cv2.rectangle(converted,pt1=(200,140),pt2=(510,150),color=(0,255,0),thickness = 20)
plt.imshow(converted)


cv2.rectangle(converted,pt1=(200,180),pt2=(510,190),color=(0,0,0),thickness = 10)
plt.imshow(converted)
